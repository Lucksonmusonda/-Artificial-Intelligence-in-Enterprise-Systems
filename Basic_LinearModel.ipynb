# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucksonmusonda/-Artificial-Intelligence-in-Enterprise-Systems/blob/main/Basic_LinearModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# Generate data
np.random.seed(42)
X = np.random.rand(100, 1)  # Input feature (1D)
y = 2 * X + 1 + np.random.randn(100, 1)  # Output (target) variable

# linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

# Make predictions
X_test = np.linspace(0, 1, 100).reshape(-1, 1)
y_pred = model.predict(X_test)

# %%
# Plot the data and the regression line
plt.scatter(X, y, label="Data points")
plt.plot(X_test, y_pred, color="red", label="Regression line")
plt.xlabel("Input feature (X)")
plt.ylabel("Output (y)")
plt.title("Linear Regression Example")
plt.legend()
plt.show()
